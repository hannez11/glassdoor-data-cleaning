# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_colwidth', None) # show complete content of a cells in table

# load data frame
df = pd.read_excel(r"C:\\Users\\g21728\\Desktop\\Test.xlsx", sheet_name="Sheet1")

# column list; show object types
# list(df.columns)

# convert float columns to int
float_columns = [ 'rating_overall','rating_balance','rating_culture','rating_career','rating_comp','rating_mgmt','helpful',]
df[float_columns] = df[float_columns].astype("Int64") #Int64 can store missing values as NaN

# convert time to year
df.insert(df.columns.get_loc("date")+1, "year", "") # insert new column after date column
df["year"] = df["date"].str[11:15]

# employee_status -> categories (0: former; 1: current)
df["employee_status"].unique()
employee_status_categories = {'Current Employee': 1, 'Former Employee': 0} # dict with categories
df["employee_status"] = df["employee_status"].replace(employee_status_categories).astype("Int64") # replace strings with ints
df.rename(columns={"employee_status": "current_employee"}, inplace=True) #inplace works with the current dataset. otherwise df["employee_status"] = ... is needed in front

# years at company -> tenure categories & full (1) vs part time (0)
# print(df["years_at_company"].unique()) # show unique values
df.insert(6, "full_time", "")
employee_status_categories = {True: 1, False: 0}
df["full_time"] = df["years_at_company"].str.contains("full-time").map(employee_status_categories).astype("Int64") # if string contains "full-time"

# tenure: cut "years at company" after "for"
df.insert(7, "tenure", "")
df["tenure"] = df["years_at_company"].str.split('for').str[1]
df["tenure"].unique()
# assign tenure categories
tenure_categories = {' more than 3 years':3, ' more than a year':2, ' more than 5 years':4,' more than 8 years':5, ' less than a year':1,' more than 10 years':6}
df["tenure"] = df["tenure"].replace(tenure_categories).astype("Int64")

# categorize recommends
print(df["recommends"].unique()) # ['Recommends' nan 'Approves of CEO' 'Positive Outlook' "Doesn't Recommend" 'Neutral Outlook' 'Negative Outlook' 'No opinion of CEO', 'Disapproves of CEO']
df['recommends'].str.contains('Outlook|CEO', case=False, regex=True).value_counts() # regex OR command
df.insert(df.columns.get_loc("recommends")+1, "outlook_mydata", "") # insert new column after date column
df["outlook_mydata"] = np.where(df['recommends'].str.contains('Outlook', case=False, regex=True) == True, df["recommends"], df["positive_outlook"]) 

df.insert(df.columns.get_loc("approves_of_CEO")+1, "approves_of_CEO_mydata", "") # insert new column after date column
df["approves_of_CEO_mydata"] = np.where(df['recommends'].str.contains('CEO', case=False, regex=True) == True, df["recommends"], df["positive_outlook"]) 

# df.info()
# df.to_csv('data-output/my-data.csv')
# CHECK IF OUTLOOK IN RECOMMENDS WAS TRANSFERRED TO OUTLOOK MY DATA
#  TO THE SAME WITH CEO APPROVAL

df.head(7)
# Out:
# ['Recommends' nan 'Approves of CEO' 'Positive Outlook' "Doesn't Recommend"
#  'Neutral Outlook' 'Negative Outlook' 'No opinion of CEO'
#  'Disapproves of CEO']
#          company_name  \
# 0     AlerusFinancial
# 1     AlerusFinancial
# 2     AlerusFinancial
# 3     AlerusFinancial
# 4     AlerusFinancial
# ...               ...
# 1081          AARCorp
# 1082          AARCorp
# 1083          AARCorp
# 1084          AARCorp
# 1085          AARCorp
#
#                                                                    date  year  \
# 0     Wed Jun 17 2020 09:14:03 GMT+0200 (MitteleuropÃ¤ische Sommerzeit)  2020
# 1     Thu Jun 11 2020 09:15:00 GMT+0200 (MitteleuropÃ¤ische Sommerzeit)  2020
# 2     Tue Jun 09 2020 06:54:06 GMT+0200 (MitteleuropÃ¤ische Sommerzeit)  2020
# 3     Tue Nov 05 2019 11:14:44 GMT+0100 (MitteleuropÃ¤ische Normalzeit)  2019
# 4     Thu Oct 24 2019 06:13:57 GMT+0200 (MitteleuropÃ¤ische Sommerzeit)  2019
# ...                                                                 ...   ...
# 1081  Sun Apr 14 2013 15:33:37 GMT+0200 (MitteleuropÃ¤ische Sommerzeit)  2013
# 1082  Thu Apr 11 2013 12:39:18 GMT+0200 (MitteleuropÃ¤ische Sommerzeit)  2013
# 1083  Wed Feb 27 2013 08:44:14 GMT+0100 (MitteleuropÃ¤ische Normalzeit)  2013
# 1084  Mon Feb 18 2013 08:36:58 GMT+0100 (MitteleuropÃ¤ische Normalzeit)  2013
# 1085  Wed Jan 30 2013 17:05:36 GMT+0100 (MitteleuropÃ¤ische Normalzeit)  2013
#
#                    employee_title          location  current_employee  \
# 0           Retirement Specialist   Minneapolis, MN                 1
# 1            Relationship Manager  East Lansing, MI                 1
# 2               Service Associate               NaN                 0
# 3      Retirement Account Analyst    Albert Lea, MN                 1
# 4              Plan Administrator               NaN                 0
# ...                           ...               ...               ...
# 1081                     Engineer     Goldsboro, NC                 1
# 1082                          NaN     Wood Dale, IL                 1
# 1083                    Logistics         AfghÄnÄ«                 0
# 1084                          NaN     Wood Dale, IL                 1
# 1085                          NaN  Indianapolis, IN                 1
#
#       full_time  tenure  \
# 0             1       3
# 1             1       3
# 2             0       2
# 3             1       3
# 4             1       4
# ...         ...     ...
# 1081          1       1
# 1082          1       2
# 1083          1       1
# 1084          1    <NA>
# 1085          1       2
#
#                                                                review_title  \
# 0                                                             Great company
# 1                                            Tremendous Company and Culture
# 2                                                    Great job for students
# 3                                                            Iâ€™m not sure
# 4                                                       Great place to work
# ...                                                                     ...
# 1081                                            Horrible to be an engineer!
# 1082  Always looking outside for expertise while ignoring inside experience
# 1083                                       AAR IS one Of The Worst companys
# 1084                                     AAR has great wellness initiatives
# 1085                                             Used, abused and underpaid
#
#                                                    years_at_company  ...  \
# 0     I have been working at Alerus full-time for more than 3 years  ...
# 1     I have been working at Alerus full-time for more than 3 years  ...
# 2                 I worked at Alerus part-time for more than a year  ...
# 3     I have been working at Alerus full-time for more than 3 years  ...
# 4                I worked at Alerus full-time for more than 5 years  ...
# ...                                                             ...  ...
# 1081      I have been working at AAR full-time for less than a year  ...
# 1082      I have been working at AAR full-time for more than a year  ...
# 1083                 I worked at AAR full-time for less than a year  ...
# 1084                           I have been working at AAR full-time  ...
# 1085      I have been working at AAR full-time for more than a year  ...
#
#      rating_comp rating_mgmt         recommends    outlook_mydata  \
# 0              3           5         Recommends  Positive Outlook
# 1              4           5         Recommends  Positive Outlook
# 2              4           5         Recommends  Positive Outlook
# 3              2           3                NaN               NaN
# 4              5           3         Recommends               NaN
# ...          ...         ...                ...               ...
# 1081           1           1  Doesn't Recommend  Negative Outlook
# 1082           2           2  Doesn't Recommend   Neutral Outlook
# 1083           5           1  Doesn't Recommend  Negative Outlook
# 1084           4           3         Recommends  Positive Outlook
# 1085           4           1  Doesn't Recommend  Negative Outlook
#
#       positive_outlook     approves_of_CEO  approves_of_CEO_mydata  helpful  \
# 0     Positive Outlook     Approves of CEO        Positive Outlook        0
# 1     Positive Outlook     Approves of CEO        Positive Outlook        0
# 2     Positive Outlook                 NaN        Positive Outlook        0
# 3                  NaN                 NaN                     NaN        0
# 4                  NaN     Approves of CEO                     NaN        0
# ...                ...                 ...                     ...      ...
# 1081  Negative Outlook  Disapproves of CEO        Negative Outlook        2
# 1082   Neutral Outlook   No opinion of CEO         Neutral Outlook        5
# 1083  Negative Outlook                 NaN        Negative Outlook        1
# 1084  Positive Outlook     Approves of CEO        Positive Outlook        0
# 1085  Negative Outlook   No opinion of CEO        Negative Outlook        1
#
#                                                                                                                                                                                                                                                                                 advice_to_mgmt  \
# 0                                                                                                                                                                                                                                                                                          NaN
# 1                                                                                                                                                                                                                              Keep up the good work in transparency and thoughtful leadership
# 2                                                                                                                                                                                                                                                                                          NaN
# 3                                                                                                                                                                                                                                                                       Donâ€™t pick favorites
# 4                                                                                                                                                                                                                                                                                          NaN
# ...                                                                                                                                                                                                                                                                                        ...
# 1081                                                                                                                                                                                                                                                                                       NaN
# 1082                                                                                                                                                                                  Quit going outside for people and give internal employees a chance to advance. Stop hiring future idiots
# 1083  I understand things change. AAR hired me and managment didnt even try and find another position for me, I just found out that AAR has done a lot of people like this. When you hire someone and the company get in a tight dont just fire them, AAR management is really bad about that.
# 1084                                                                                                                                                                                                                 encourage their employees to take advantage of these wellness initiatives
# 1085                                                                              Be straight forward with employees. Stop letting good workers leave (pay better) and replacing them with inexperienced or incompent workers. Invest in the company (upgrade and replace outdated equipment).
#
#                                                                                           response
# 0                                                                                              NaN
# 1                                                                                              NaN
# 2                                                                                              NaN
# 3                                                                                              NaN
# 4                                                                                              NaN
# ...                                                                                            ...
# 1081                                                                                           NaN
# 1082                                                                                           NaN
# 1083  Not sure what to do/say, yet contact information is gdellinger@aarcorp.com.. . V/R,. . G-Man
# 1084                                                                                           NaN
# 1085                                                                                           NaN
#
# [1086 rows x 26 columns]

# %%
# drop cleaned columns
df.drop(columns=["date", "years_at_company"], inplace=True)

# show table
df.head(10)
# Out:
#       company_name  year               employee_title          location  \
# 0  AlerusFinancial  2020        Retirement Specialist   Minneapolis, MN
# 1  AlerusFinancial  2020         Relationship Manager  East Lansing, MI
# 2  AlerusFinancial  2020            Service Associate               NaN
# 3  AlerusFinancial  2019   Retirement Account Analyst    Albert Lea, MN
# 4  AlerusFinancial  2019           Plan Administrator               NaN
# 5  AlerusFinancial  2019            Service Associate   Grand Forks, ND
# 6  AlerusFinancial  2019     Administrative Assistant               NaN
# 7  AlerusFinancial  2019                          NaN               NaN
# 8  AlerusFinancial  2018      IT Technical Specialist   Minneapolis, MN
# 9  AlerusFinancial  2018                          NaN               NaN
#
#    current_employee  full_time  tenure                         review_title  \
# 0                 1          1       3                        Great company
# 1                 1          1       3       Tremendous Company and Culture
# 2                 0          0       2               Great job for students
# 3                 1          1       3                       Iâ€™m not sure
# 4                 0          1       4                  Great place to work
# 5                 1          0       3  Overall, great company to work for!
# 6                 0          1    <NA>                       Good first job
# 7                 1          1    <NA>                   Good place to work
# 8                 1          1       3              IT Technical Specialist
# 9                 0          1    <NA>                Account Administrator
#
#                                                                                                                                                     pros  \
# 0                                                                                                                     The care about you and your family
# 1  Diversified financial services company with various opportunities within the organization. Transparent C Suite leadership. Inclusive company culture.
# 2                                                                                                                Good pay for college students, flexible
# 3                                                                                                                Flexible schedule, working with clients
# 4                                                                                                  Flexible, friendly enviroment, great benefits and pay
# 5                                      Alerus is a great place to work as they are flexible and typically willing to work with many different situations
# 6                                                                                     18 days PTO, coworkers and most customers were great to work with.
# 7                                                          supportive of work/life balance, tools to help with growth, and the company has great values.
# 8                                                                                                              flexible schedule for employees work week
# 9                                                                                                      Great benefits, growing company. Room for growth.
#
#                                                                                                               cons  \
# 0                                 Lacks training new employees. Many different databases to search for information
# 1  Multiple systems that store data and information can make it challenging to find specific info, resources, etc.
# 2                                                                         Could use some newer, updates technology
# 3                                                                                                Unable to move up
# 4                                                         Some of the managers clearly have favorites and it shows
# 5                                                                                  Human Resources lacks at Alerus
# 6                                                                                  No room for advancement/low pay
# 7                                                                                         none that I can think of
# 8                                                                                not enough training when starting
# 9                   Watch out who you report to, it can make or break your experience there. Lots a poor managers.
#
#    ...  rating_career  rating_comp  rating_mgmt        recommends  \
# 0  ...              3            3            5        Recommends
# 1  ...              5            4            5        Recommends
# 2  ...              4            4            5        Recommends
# 3  ...              3            2            3               NaN
# 4  ...              3            5            3        Recommends
# 5  ...              3            5            4        Recommends
# 6  ...              3            4            4   Approves of CEO
# 7  ...              4            4            4        Recommends
# 8  ...              3            4            3        Recommends
# 9  ...              2            3            3  Positive Outlook
#
#    outlook_mydata  positive_outlook  approves_of_CEO helpful  \
# 0                  Positive Outlook  Approves of CEO       0
# 1                  Positive Outlook  Approves of CEO       0
# 2                  Positive Outlook              NaN       0
# 3                               NaN              NaN       0
# 4                               NaN  Approves of CEO       0
# 5                  Positive Outlook  Approves of CEO       0
# 6                               NaN              NaN       0
# 7                  Positive Outlook  Approves of CEO       0
# 8                  Positive Outlook  Approves of CEO       0
# 9                               NaN  Approves of CEO       0
#
#                                                     advice_to_mgmt response
# 0                                                              NaN      NaN
# 1  Keep up the good work in transparency and thoughtful leadership      NaN
# 2                                                              NaN      NaN
# 3                                           Donâ€™t pick favorites      NaN
# 4                                                              NaN      NaN
# 5                                                              NaN      NaN
# 6                                                              NaN      NaN
# 7                                                              NaN      NaN
# 8              yes there is room to advance in certain departments      NaN
# 9                                                              NaN      NaN
#
# [10 rows x 23 columns]
